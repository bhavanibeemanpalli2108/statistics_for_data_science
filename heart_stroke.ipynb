# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
data=pd.read_csv('heartstroke.csv')
df=pd.DataFrame(data)
print(df)
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
data
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %% [markdown]
# ## EDA:<DATASET>
# 1. load and overview
# 2. Cleaning(missing,  dupes,  dtypes)
# 3. uni, bi, and  multi variate analysis
# 4. outliers-IQR
# 5. Feature Engineering
# 6. key insights

# %% [markdown]
# ## To load and analyise overview of the data

# %%
#load the dataset
data=pd.read_csv('heartstroke.csv')

# %%
#basic information  and overview of the dataset
print("shape of the datset:",data.shape)
print("\ndata info:",data.info())

# summary statistics
print("\nsummary statistics:",data.describe(include='all'))
print("\ndataset coulmns:",data.columns)
# Out:
# shape of the datset: (5110, 12)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB
#
# data info: None
#
# ...

# %%
# to check the missing values in the data
data.isna().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
print(f"unique data values of feature id{data['id'].unique()}")
print(f"unique data values of feature gender{data['gender'].unique()}")
print(f"unique data values of feature hypertension{data['hypertension'].unique()}")
print(f"unique data values of feature heart_disease{data['heart_disease'].unique()}")
print(f"unique data values of feature age{data['age'].unique()}")
print(f"unique data values of feature ever_married{data['ever_married'].unique()}")
print(f"unique data values of feature work_type{data['work_type'].unique()}")  
print(f"unique data values of feature Residence_type{data['Residence_type'].unique()}")
print(f"unique data values of feature smoking_status{data['smoking_status'].unique()}")
print(f"unique data values of feature stroke{data['stroke'].unique()}")
# Out:
# unique data values of feature id[ 9046 51676 31112 ... 19723 37544 44679]
# unique data values of feature gender['Male' 'Female' 'Other']
# unique data values of feature hypertension[0 1]
# unique data values of feature heart_disease[1 0]
# unique data values of feature age[6.70e+01 6.10e+01 8.00e+01 4.90e+01 7.90e+01 8.10e+01 7.40e+01 6.90e+01
#  5.90e+01 7.80e+01 5.40e+01 5.00e+01 6.40e+01 7.50e+01 6.00e+01 5.70e+01
#  7.10e+01 5.20e+01 8.20e+01 6.50e+01 5.80e+01 4.20e+01 4.80e+01 7.20e+01
#  6.30e+01 7.60e+01 3.90e+01 7.70e+01 7.30e+01 5.60e+01 4.50e+01 7.00e+01
#  6.60e+01 5.10e+01 4.30e+01 6.80e+01 4.70e+01 5.30e+01 3.80e+01 5.50e+01
#  1.32e+00 4.60e+01 3.20e+01 1.40e+01 3.00e+00 8.00e+00 3.70e+01 4.00e+01
#  3.50e+01 2.00e+01 4.40e+01 2.50e+01 2.70e+01 2.30e+01 1.70e+01 1.30e+01
#  4.00e+00 1.60e+01 2.20e+01 3.00e+01 2.90e+01 1.10e+01 2.10e+01 1.80e+01
#  3.30e+01 2.40e+01 3.40e+01 3.60e+01 6.40e-01 4.10e+01 8.80e-01 5.00e+00
# ...

# %%
print(f'length of the unique features of id: {len(data['id'].unique())}')
print(f'length of the unique features of gender: {len(data['gender'].unique())}')
print(f'length of the unique features of hypertension: {len(data['hypertension'].unique())}')        
print(f'length of the unique features of heart_disease: {len(data['heart_disease'].unique())}')
print(f'length of the unique features of age: {len(data['age'].unique())}')
print(f'length of the unique features of ever_married: {len(data['ever_married'].unique())}')
print(f'length of the unique features of work_type: {len(data['work_type'].unique())}')
print(f'length of the unique features of Residence_type: {len(data['Residence_type'].unique())}')
print(f'length of the unique features of smoking status: {len(data['smoking_status'].unique())}')
print(f'length of the unique features of stroke: {len(data['stroke'].unique())}')
# Out:
# length of the unique features of id: 5110
# length of the unique features of gender: 3
# length of the unique features of hypertension: 2
# length of the unique features of heart_disease: 2
# length of the unique features of age: 104
# length of the unique features of ever_married: 2
# length of the unique features of work_type: 5
# length of the unique features of Residence_type: 2
# length of the unique features of smoking status: 4
# length of the unique features of stroke: 2
