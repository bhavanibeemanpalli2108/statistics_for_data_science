# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv('loan_approved.csv')

# %%
print(dataset.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Loan_ID                 614 non-null    object
#  1   Gender                  601 non-null    object
#  2   Married                 611 non-null    object
#  3   Dependents              599 non-null    object
#  4   Education               614 non-null    object
#  5   Self_Employed           582 non-null    object
#  6   ApplicantIncome         614 non-null    int64
#  7   CoapplicantIncome       614 non-null    float64
#  8   LoanAmount              592 non-null    float64
#  9   Loan_Amount_Term        600 non-null    float64
#  10  Credit_History          564 non-null    float64
#  11  Property_Area           614 non-null    object
#  12  Loan_Status (Approved)  614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB
# None

# %% [markdown]
# ## datatypes
# * loan id: unique
# 1. gender: nomianl
# 2. married: nominal
# 3. dependent:
# 4. education: nominal
# 5. self employed: nominal
# 6. application income: continuous
# 7. coapplicant income: continuous
# 8. loan amount: dis
# 9. loan_amouny_term: discrete
# 10. credit_history:
# 11. property_area: nominal
# 12. loan_status: nominal

# %%
dataset['Loan_ID'].unique()
# Out:
# array(['LP001002', 'LP001003', 'LP001005', 'LP001006', 'LP001008',
#        'LP001011', 'LP001013', 'LP001014', 'LP001018', 'LP001020',
#        'LP001024', 'LP001027', 'LP001028', 'LP001029', 'LP001030',
#        'LP001032', 'LP001034', 'LP001036', 'LP001038', 'LP001041',
#        'LP001043', 'LP001046', 'LP001047', 'LP001050', 'LP001052',
#        'LP001066', 'LP001068', 'LP001073', 'LP001086', 'LP001087',
#        'LP001091', 'LP001095', 'LP001097', 'LP001098', 'LP001100',
#        'LP001106', 'LP001109', 'LP001112', 'LP001114', 'LP001116',
#        'LP001119', 'LP001120', 'LP001123', 'LP001131', 'LP001136',
#        'LP001137', 'LP001138', 'LP001144', 'LP001146', 'LP001151',
#        'LP001155', 'LP001157', 'LP001164', 'LP001179', 'LP001186',
#        'LP001194', 'LP001195', 'LP001197', 'LP001198', 'LP001199',
#        'LP001205', 'LP001206', 'LP001207', 'LP001213', 'LP001222',
#        'LP001225', 'LP001228', 'LP001233', 'LP001238', 'LP001241',
# ...

# %%
print(dataset.shape)
# Out:
# (614, 13)

# %%
len(dataset['Loan_ID'].unique())
# Out:
# 614

# %% [markdown]
# ##  these kind of column falls under nominal category but they don't have any significance

# %%
len(dataset['Gender'].unique())
# Out:
# 3

# %%
dataset['Gender'].unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
len(dataset['Gender'])
# Out:
# 614

# %% [markdown]
# ## gender is normal
# ## but it depends  now the data

# %%
len(dataset['Married'].unique())
# Out:
# 3

# %%
dataset['Married'].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %% [markdown]
# ## Married - nominal

# %%
len(dataset['Dependents'].unique())
# Out:
# 5

# %%
dataset['Dependents'].unique()
# Out:
# array(['0', '1', '2', '3+', nan], dtype=object)

# %% [markdown]
# ## Dependent - categorical(ordinal)
# ### it is not nominal data

# %%
len(dataset['Education'].unique())
# Out:
# 2

# %%
dataset['Education'].unique()
# Out:
# array(['Graduate', 'Not Graduate'], dtype=object)

# %% [markdown]
# ## education - nominal

# %%
len(dataset['Self_Employed'].unique())
# Out:
# 3

# %%
dataset['Self_Employed'].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %% [markdown]
# ##  self_employed- nominal

# %%
len(dataset['ApplicantIncome'].unique())
# Out:
# 505

# %%
dataset['ApplicantIncome'].unique()
# Out:
# array([ 5849,  4583,  3000,  2583,  6000,  5417,  2333,  3036,  4006,
#        12841,  3200,  2500,  3073,  1853,  1299,  4950,  3596,  3510,
#         4887,  2600,  7660,  5955,  3365,  3717,  9560,  2799,  4226,
#         1442,  3750,  4166,  3167,  4692,  3500, 12500,  2275,  1828,
#         3667,  3748,  3600,  1800,  2400,  3941,  4695,  3410,  5649,
#         5821,  2645,  4000,  1928,  3086,  4230,  4616, 11500,  2708,
#         2132,  3366,  8080,  3357,  3029,  2609,  4945,  5726, 10750,
#         7100,  4300,  3208,  1875,  4755,  5266,  1000,  3333,  3846,
#         2395,  1378,  3988,  2366,  8566,  5695,  2958,  6250,  3273,
#         4133,  3620,  6782,  2484,  1977,  4188,  1759,  4288,  4843,
#        13650,  4652,  3816,  3052, 11417,  7333,  3800,  2071,  5316,
#         2929,  3572,  7451,  5050, 14583,  2214,  5568, 10408,  5667,
#         2137,  2957,  3692, 23803,  3865, 10513,  6080, 20166,  2014,
# ...

# %% [markdown]
# ## applicantincome - continuous

# %%
len(dataset['CoapplicantIncome'].unique())
# Out:
# 287

# %%
dataset['CoapplicantIncome'].isna().sum()
# Out:
# np.int64(0)

# %%
import seaborn as sns

# %%
sns.histplot(dataset['CoapplicantIncome'])
# Out:
# <Axes: xlabel='CoapplicantIncome', ylabel='Count'>

# %% [markdown]
# ##  it states that there is no coapplocant  income  to few of the applicant's

# %% [markdown]
# ### the data in which coapplicant;s income is none  or 0  then such data is classified as no sifnificance features

# %%
len(dataset['LoanAmount'].unique())
# Out:
# 204

# %%
dataset['LoanAmount'].unique()
# Out:
# array([ nan, 128.,  66., 120., 141., 267.,  95., 158., 168., 349.,  70.,
#        109., 200., 114.,  17., 125., 100.,  76., 133., 115., 104., 315.,
#        116., 112., 151., 191., 122., 110.,  35., 201.,  74., 106., 320.,
#        144., 184.,  80.,  47.,  75., 134.,  96.,  88.,  44., 286.,  97.,
#        135., 180.,  99., 165., 258., 126., 312., 136., 172.,  81., 187.,
#        113., 176., 130., 111., 167., 265.,  50., 210., 175., 131., 188.,
#         25., 137., 160., 225., 216.,  94., 139., 152., 118., 185., 154.,
#         85., 259., 194.,  93., 370., 182., 650., 102., 290.,  84., 242.,
#        129.,  30., 244., 600., 255.,  98., 275., 121.,  63., 700.,  87.,
#        101., 495.,  67.,  73., 260., 108.,  58.,  48., 164., 170.,  83.,
#         90., 166., 124.,  55.,  59., 127., 214., 240.,  72.,  60., 138.,
#         42., 280., 140., 155., 123., 279., 192., 304., 330., 150., 207.,
#        436.,  78.,  54.,  89., 143., 105., 132., 480.,  56., 159., 300.,
# ...

# %%
### loanamount: continuous

# %%
len(dataset['Loan_Amount_Term'].unique())
# Out:
# 11

# %%
dataset['Loan_Amount_Term'].unique()
# Out:
# array([360., 120., 240.,  nan, 180.,  60., 300., 480.,  36.,  84.,  12.])

# %% [markdown]
# ### loan amount term- dicrete numerical data

# %%
len(dataset['Credit_History'].unique())# categorical nominal
# Out:
# 3

# %%
dataset['Credit_History'].unique()# discrete column
# Out:
# array([ 1.,  0., nan])

# %% [markdown]
# ### credit history: discrete

# %%
len(dataset['Property_Area'].unique())
# Out:
# 3

# %%
dataset['Property_Area'].unique()
# Out:
# array(['Urban', 'Rural', 'Semiurban'], dtype=object)

# %% [markdown]
# ### property name- ordinal

# %%
len(dataset['Loan_Status (Approved)'].unique())
# Out:
# 2

# %%
dataset['Loan_Status (Approved)'].unique()
# Out:
# array(['Y', 'N'], dtype=object)

# %% [markdown]
# ### loan_status - nominal

# %% [markdown]
# ##  Filling the missing values

# %%
df['col1'].fillna(df['col1'].mean(), inplace=True)
# The 'inplace=True' modifies the original DataFrame

# %%
data=pd.read_csv('loan_approved.csv')

# %%
df=pd.DataFrame(data)
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
data.isna()
# Out:
#      Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0      False   False    False       False      False          False
# 1      False   False    False       False      False          False
# 2      False   False    False       False      False          False
# 3      False   False    False       False      False          False
# 4      False   False    False       False      False          False
# ..       ...     ...      ...         ...        ...            ...
# 609    False   False    False       False      False          False
# 610    False   False    False       False      False          False
# 611    False   False    False       False      False          False
# 612    False   False    False       False      False          False
# 613    False   False    False       False      False          False
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              False              False        True             False
# ...

# %%
plt.hist(data['LoanAmount'])
# Out:
# (array([ 72., 310., 143.,  33.,  15.,   6.,   5.,   3.,   3.,   2.]),
#  array([  9. ,  78.1, 147.2, 216.3, 285.4, 354.5, 423.6, 492.7, 561.8,
#         630.9, 700. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.histplot(data['LoanAmount'])
# Out:
# <Axes: xlabel='LoanAmount', ylabel='Count'>

# %% [markdown]
# ### to identify we should use as a feature
# #### 1. in machine learning we  have feature selection using visualization
# #### 2.

# %% [markdown]
# ### target column/dependent column/ y column

# %%
# getting the values iin dependents
print(len(data.loc[data['Dependents'].isnull(), 'Dependents']))
# Out:
# 15

# %%
data.Dependents.value_counts()
# Out:
# Dependents
# 0     345
# 1     102
# 2     101
# 3+     51
# Name: count, dtype: int64

# %%
sns.countplot(x='Dependents',data=data,hue='Loan_Status (Approved)')
# Out:
# <Axes: xlabel='Dependents', ylabel='count'>
